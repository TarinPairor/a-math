# %%
from v4 import generate_equations

# %%
import time
start = time.time()
generate_equations(["-","10","=", "-","8","-","1","/","2"])
# print(time.time() - start)
# Out:
# ['-10/-1-2=8',
#  '-10/-1-8=2',
#  '-10/1=-2-8',
#  '-10/1=-8-2',
#  '-10=-2-8/1',
#  '-10=-2/1-8',
#  '-10=-8-2/1',
#  '-10=-8/1-2',
#  '-10=2/-1-8',
#  '-10=8/-1-2',
#  '-2-10/-1=8',
#  '-2-8=10/-1',
#  '-2/-1=10-8',
#  '-8-10/-1=2',
#  '-8-2=10/-1',
#  '-8/-1=10-2']

# %%
from extensions import generate_additive_zero_extensions
generate_additive_zero_extensions(["-","10","+", "-","8","-","1","/","2"])
# Out:
# ['10-2-8',
#  '2+8-10',
#  '+10-2-8',
#  '+10-8-2',
#  '-2+10-8',
#  '-8+10-2',
#  '10-2-8+',
#  '10-8-2+',
#  '+-2-8-10',
#  '+-8-2-10',
#  '-2-8-10+',
#  '-8-2-10+',
#  '10-2-8/1',
#  '10-2/1-8',
#  '10/1-2-8',
#  '2+8-10/1',
#  '2+8/1-10',
#  '2/1+8-10',
#  '+10-2-8/1',
#  '+10-2/1-8',
#  '+10-8-2/1',
#  '+10-8/1-2',
#  '+10/1-2-8',
#  '+10/1-8-2',
#  '-2+10-8/1',
#  '-2+10/1-8',
#  '-2/1+10-8',
#  '-8+10-2/1',
#  '-8+10/1-2',
#  '-8/1+10-2',
#  '10+2/-1-8',
#  '10+8/-1-2',
#  '10-2-8/1+',
#  '10-2/1-8+',
#  '10-8-2/1+',
#  '10-8/1-2+',
#  '10/1-2-8+',
#  '10/1-8-2+',
#  '2-10-8/-1',
#  '8-10-2/-1',
#  '+-2-8-10/1',
#  '+-2-8/1-10',
#  '+-2/1-8-10',
#  '+-8-2-10/1',
#  '+-8-2/1-10',
#  '+-8/1-2-10',
#  '+10-2-8/-1',
#  '+10-8-2/-1',
#  '+2-10-8/-1',
#  '+2/-1-8-10',
#  '+8-10-2/-1',
#  '-10+2-8/-1',
#  '-10+8-2/-1',
#  '-2-8-10/1+',
#  '-2-8/1-10+',
#  '-2/-1+8-10',
#  '-2/1-8-10+',
#  '-8-2-10/1+',
#  '-8-2/1-10+',
#  '-8/-1+2-10',
#  '-8/1-2-10+',
#  '10-2-8/-1+',
# ...

# %%
generate_equations(["2","=","2", "2"])
# generate_equations(["3","=","1",'+','2'])

# generate_equations(["3","2","*","4",'=','8'])

# page 41
# generate_equations(["4","7","-",'9','*','3','=','20','+','1','5','/','7','*','0'])
# generate_equations(["3","7","=","7","4","/","2"])
# generate_equations(["4","7","-",'2','7','=','20','+','7','*','0'])
# generate_equations(["4","0",'2','7','=','2','+','0','*','0'])
# Out:
# []
