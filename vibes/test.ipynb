# %%
from v4 import generate_equations

# %%
generate_equations(["3","=","1",'+','2'])
# Out:
# []

# %%
# generate_equations(["2","=","2",'2','2'])
generate_equations(["3","=","1",'+','2'])
# Out:
# ['22=22', '2=2', '2=2=2']
